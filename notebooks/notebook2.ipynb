# %%
## Setup & config

# Libraries
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import mne
from scipy.stats import ttest_ind
import warnings

# Ignore noisy warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# Move to your project directory
# %cd /Users/diarmuidlenihan/Documents/eeg_proj

# Confirm the working directory and files
print("CWD now:", Path().resolve())
print("data/raw exists ->", Path("data/raw").exists())

# EEG configuration
RAW_DIR = Path("data/raw")   # Folder where your Origin_*.txt files are stored
SFREQ = 250.0                # Sampling frequency in Hz
CH_NAMES = [
    'Fp1','Fp2','F3','F4','C3','C4','P3','P4','O1','O2',
    'F7','F8','T7','T8','P7','P8','Fz','Cz','Pz','Oz',
    'FC1','FC2','CP1','CP2','FC5','FC6','CP5','CP6',
    'TP9','TP10','POz'
]

# Quick check that files are visible
files_check = sorted(RAW_DIR.glob("Origin_*.txt"))
print("Files found:", len(files_check))
for f in files_check[:5]:
    print(" -", f.name)
# Out:
# /Users/diarmuidlenihan/Documents/eeg_proj
# CWD now: /Users/diarmuidlenihan/Documents/eeg_proj
# data/raw exists -> True
# Files found: 12
#  - Origin_H1.txt
#  - Origin_H2.txt
#  - Origin_H3.txt
#  - Origin_H4.txt
#  - Origin_H5.txt

# %%
## Helper functions

def load_txt_eeg(path):
    """
    Load EEG data from a text file with a header of channel names.
    Returns array of shape (31, n_times) in VOLTS.
    """
    try:
        # Try reading with pandas automatic separator detection
        df = pd.read_csv(path, sep=None, engine="python")
    except Exception:
        # Fallback to whitespace-only
        df = pd.read_csv(path, delim_whitespace=True, engine="python")

    # If no string headers, re-read with no header
    if not any(isinstance(c, str) for c in df.columns):
        df = pd.read_csv(path, sep=None, engine="python", header=None)

    # Drop obvious non-signal columns
    to_drop = []
    for c in df.columns:
        if isinstance(c, str):
            s = c.strip().lower()
            if s.startswith("time") or s.startswith("sample") or c.startswith("Unnamed"):
                to_drop.append(c)
    df = df.drop(columns=to_drop, errors="ignore")

    # Reorder columns to expected channel order if headers match
    expected = set(CH_NAMES)
    cols = [c.strip() if isinstance(c, str) else c for c in df.columns]
    df.columns = cols
    have = [c for c in cols if c in expected]

    if len(have) == len(CH_NAMES):
        df = df[CH_NAMES]
        X = df.to_numpy(dtype=float).T          # shape (31, n_times)
    else:
        arr = df.to_numpy(dtype=float, copy=True)
        if arr.shape[1] == len(CH_NAMES):       # (n_times, 31)
            X = arr.T
        elif arr.shape[0] == len(CH_NAMES):     # (31, n_times)
            X = arr
        else:
            raise ValueError(f"{Path(path).name}: unexpected shape {arr.shape}")

    # Convert microvolts to volts if needed
    if np.nanmax(np.abs(X)) > 1e-3:
        X = X * 1e-6

    return X


def band_power(raw, fmin, fmax):
    """
    Compute mean power in a frequency band for a given MNE Raw object.
    """
    psd, freqs = mne.time_frequency.psd_welch(
        raw, fmin=fmin, fmax=fmax, n_fft=2048, n_overlap=1024
    )
    return float(psd.mean(axis=1).mean())

# %%
## File processing

files = sorted(RAW_DIR.glob("Origin_*.txt"))
print("Processing", len(files), "files...")

rows = []

for f in files:
    group = "HC" if "_H" in f.stem else "PTSD"
    subj = f.stem.replace("Origin_", "")

    # 1. Load data
    X = load_txt_eeg(f)

    # 2. Build MNE Raw object
    info = mne.create_info(CH_NAMES, SFREQ, ch_types="eeg")
    raw = mne.io.RawArray(X, info, verbose=False)
    raw.set_montage("standard_1020", on_missing='ignore')
    raw.filter(1., 40., fir_design='firwin', verbose=False)

    # 3. Compute features
    alpha = band_power(raw, 8., 12.)
    beta = band_power(raw, 13., 30.)

    # 4. Store results
    rows.append({
        "subject": subj,
        "group": group,
        "alpha_power": alpha,
        "beta_power": beta
    })

print("Rows collected:", len(rows))
df = pd.DataFrame(rows).sort_values(["group","subject"])
display(df.head())

# Optional: save for later use
df.to_csv("outputs/results/band_power_2018.csv", index=False)
# Out:
# Processing 12 files...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 19
#      17 raw = mne.io.RawArray(X, info, verbose=False)
#      18 raw.set_montage("standard_1020", on_missing='ignore')
# ---> 19 raw.filter(1., 40., fir_design='firwin', verbose=False)
#      21 # 3. Compute features
#      22 alpha = band_power(raw, 8., 12.)
#
# File /opt/anaconda3/envs/eeg_project/lib/python3.11/site-packages/mne/io/base.py:1015, in BaseRaw.filter(self, l_freq, h_freq, picks, filter_length, l_trans_bandwidth, h_trans_bandwidth, n_jobs, method, iir_params, phase, fir_window, fir_design, skip_by_annotation, pad, verbose)
#    1008 @copy_doc(FilterMixin.filter)
#    1009 def filter(self, l_freq, h_freq, picks=None, filter_length='auto',
#    1010            l_trans_bandwidth='auto', h_trans_bandwidth='auto', n_jobs=1,
#    (...)   1013            skip_by_annotation=('edge', 'bad_acq_skip'),
#    1014            pad='reflect_limited', verbose=None):  # noqa: D102
# -> 1015     return super().filter(
#    1016         l_freq, h_freq, picks, filter_length, l_trans_bandwidth,
#    1017         h_trans_bandwidth, n_jobs, method, iir_params, phase,
#    1018         fir_window, fir_design, skip_by_annotation, pad, verbose)
#
# File <decorator-gen-116>:22, in filter(self, l_freq, h_freq, picks, filter_length, l_trans_bandwidth, h_trans_bandwidth, n_jobs, method, iir_params, phase, fir_window, fir_design, skip_by_annotation, pad, verbose)
#
# File /opt/anaconda3/envs/eeg_project/lib/python3.11/site-packages/mne/filter.py:2006, in FilterMixin.filter(self, l_freq, h_freq, picks, filter_length, l_trans_bandwidth, h_trans_bandwidth, n_jobs, method, iir_params, phase, fir_window, fir_design, skip_by_annotation, pad, verbose)
#    2002 for si, (start, stop) in enumerate(zip(onsets, ends)):
#    2003     # Only output filter params once (for info level), and only warn
#    2004     # once about the length criterion (longest segment is too short)
#    2005     use_verbose = verbose if si == max_idx else 'error'
# -> 2006     filter_data(
#    2007         self._data[:, start:stop], self.info['sfreq'], l_freq, h_freq,
#    2008         picks, filter_length, l_trans_bandwidth, h_trans_bandwidth,
#    2009         n_jobs, method, iir_params, copy=False, phase=phase,
#    2010         fir_window=fir_window, fir_design=fir_design, pad=pad,
#    2011         verbose=use_verbose)
#    2012 # update info if filter is applied to all data channels,
#    2013 # and it's not a band-stop filter
#    2014 _filt_update_info(self.info, update_info, l_freq, h_freq)
#
# File <decorator-gen-111>:22, in filter_data(data, sfreq, l_freq, h_freq, picks, filter_length, l_trans_bandwidth, h_trans_bandwidth, n_jobs, method, iir_params, copy, phase, fir_window, fir_design, pad, verbose)
#
# File /opt/anaconda3/envs/eeg_project/lib/python3.11/site-packages/mne/filter.py:817, in filter_data(data, sfreq, l_freq, h_freq, picks, filter_length, l_trans_bandwidth, h_trans_bandwidth, n_jobs, method, iir_params, copy, phase, fir_window, fir_design, pad, verbose)
#     815 data = _check_filterable(data)
#     816 iir_params, method = _check_method(method, iir_params)
# --> 817 filt = create_filter(
#     818     data, sfreq, l_freq, h_freq, filter_length, l_trans_bandwidth,
#     819     h_trans_bandwidth, method, iir_params, phase, fir_window, fir_design)
#     820 if method in ('fir', 'fft'):
#     821     data = _overlap_add_filter(data, filt, None, phase, picks, n_jobs,
#     822                                copy, pad)
#
# File <decorator-gen-112>:24, in create_filter(data, sfreq, l_freq, h_freq, filter_length, l_trans_bandwidth, h_trans_bandwidth, method, iir_params, phase, fir_window, fir_design, verbose)
#
# File /opt/anaconda3/envs/eeg_project/lib/python3.11/site-packages/mne/filter.py:1067, in create_filter(data, sfreq, l_freq, h_freq, filter_length, l_trans_bandwidth, h_trans_bandwidth, method, iir_params, phase, fir_window, fir_design, verbose)
#    1064                 raise ValueError('Stop bands are not sufficiently '
#    1065                                  'separated.')
#    1066 if method == 'fir':
# -> 1067     out = _construct_fir_filter(sfreq, freq, gain, filter_length, phase,
#    1068                                 fir_window, fir_design)
#    1069 return out
#
# File /opt/anaconda3/envs/eeg_project/lib/python3.11/site-packages/mne/filter.py:389, in _construct_fir_filter(sfreq, freq, gain, filter_length, phase, fir_window, fir_design)
#     387     h = minimum_phase(h)
#     388 else:
# --> 389     h = fir_design(N, freq, gain, window=fir_window)
#     390 assert h.size == N
#     391 att_db, att_freq = _filter_attenuation(h, freq, gain)
#
# File /opt/anaconda3/envs/eeg_project/lib/python3.11/site-packages/mne/filter.py:313, in _firwin_design(N, freq, gain, window, sfreq)
#     308     raise ValueError('The requested filter length %s is too short '
#     309                      'for the requested %0.2f Hz transition band, '
#     310                      'which requires %s samples'
#     311                      % (N, transition * sfreq / 2., this_N))
#     312 # Construct a lowpass
# --> 313 this_h = firwin(this_N, (prev_freq + this_freq) / 2.,
#     314                 window=window, pass_zero=True, nyq=freq[-1])
#     315 assert this_h.shape == (this_N,)
#     316 offset = (N - this_N) // 2
#
# TypeError: firwin() got an unexpected keyword argument 'nyq'

# %%
## Stats & plots

# T-tests for group differences
for band in ["alpha_power", "beta_power"]:
    a = df[df.group=="PTSD"][band]
    b = df[df.group=="HC"][band]
    t, p = ttest_ind(a, b, equal_var=False)
    print(f"{band}: t={t:.2f}, p={p:.4f}")

# Simple bar plot
plt.bar(["PTSD","HC"], [
    df[df.group=="PTSD"]["alpha_power"].mean(),
    df[df.group=="HC"]["alpha_power"].mean()
])
plt.ylabel("Mean Alpha Power (a.u.)")
plt.title("Alpha Power by Group")
plt.show()
